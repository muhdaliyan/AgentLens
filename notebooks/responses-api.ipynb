# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
# Out:
# True

# %%
client = OpenAI(
    api_key=os.environ.get('MODEL_KEY'),
    base_url=os.environ.get('BASE_URL')
)

# %%
response = client.responses.create(
    model=os.environ.get('MODEL_NAME'),
    input='what is an AI Agent'
)

# %%
print(response)
# Out:
# Response(id='resp_278192', created_at=1775539375.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gemini-3-flash-preview', object='response', output=[ResponseReasoningItem(id='rs_resp_278192', summary=[Summary(text='**Defining AI Agent Concepts**\n\nI\'m now focusing on defining the AI agent, specifically differentiating it from simpler chatbots. The core concept is that it *acts*, not just responds. I\'m breaking down the crucial components: perception (input), reasoning (like an LLM), and action. I\'m striving for clarity and accessibility in this explanation.\n\n\n**Clarifying Core Features**\n\nI\'m now diving deeper into the nuances of autonomy and tool usage, highlighting how these capabilities distinguish an AI agent. Specifically, my thought process outlines autonomy as the key feature, enabling agents to set their own sub-tasks. I\'m structuring the explanation with an elevator pitch, a "brain vs. body" analogy, and key characteristics of how it works. I\'m focusing on defining core characteristics such as tool use, reasoning, and memory to solidify the concepts. I\'m outlining an example goal and plan to showcase the process.\n\n\n', type='summary_text')], type='reasoning', content=None, encrypted_content='**Defining AI Agent Concepts**\n\nI\'m now focusing on defining the AI agent, specifically differentiating it from simpler chatbots. The core concept is that it *acts*, not just responds. I\'m breaking down the crucial components: perception (input), reasoning (like an LLM), and action. I\'m striving for clarity and accessibility in this explanation.\n\n\n**Clarifying Core Features**\n\nI\'m now diving deeper into the nuances of autonomy and tool usage, highlighting how these capabilities distinguish an AI agent. Specifically, my thought process outlines autonomy as the key feature, enabling agents to set their own sub-tasks. I\'m structuring the explanation with an elevator pitch, a "brain vs. body" analogy, and key characteristics of how it works. I\'m focusing on defining core characteristics such as tool use, reasoning, and memory to solidify the concepts. I\'m outlining an example goal and plan to showcase the process.\n\n\n', status=None), ResponseOutputMessage(id='msg_221268', content=[ResponseOutputText(annotations=[], text='At its simplest, an **AI Agent** is a system that uses Artificial Intelligence to perform tasks autonomously to achieve a specific goal.\n\nWhile a standard AI (like a basic chatbot) answers questions, an AI Agent **takes actions.**\n\nThink of it this way: \n*   **Standard AI (ChatGPT):** Like an encyclopedia. You ask it a question, and it gives you information.\n*   **AI Agent:** Like an intern. You give it a goal (e.g., "Research this company and write a summary"), and it decides which steps to take, uses tools to find information, and completes the job without you guiding every click.\n\n---\n\n### The 4 Pillars of an AI Agent\nTo be considered an "agent," the system generally needs four components:\n\n1.  **The Brain (Reasoning):** Usually a Large Language Model (LLM) like GPT-4 or Claude. It processes information, makes plans, and decides what to do next.\n2.  **Planning:** The agent breaks down a complex goal (e.g., "Plan a vacation") into smaller sub-tasks (Search flights → Find hotels → Check weather → Create itinerary).\n3.  **Memory:** \n    *   *Short-term memory:* Keeping track of the current steps.\n    *   *Long-term memory:* Learning from past interactions or retrieving data from documents.\n4.  **Tools (Action):** This is what makes it an agent. It can interact with the outside world by using APIs, searching the web, sending emails, or running code.\n\n---\n\n### How an AI Agent Works (The Loop)\nInstead of a simple "Input → Output" flow, an agent works in a **loop**:\n\n1.  **Perceive:** The agent looks at the goal and the current environment.\n2.  **Think:** It asks itself, "What is the first thing I need to do to reach this goal?"\n3.  * ...

# %%
response.output[1].content[0].text
# Out:
# 'At its simplest, an **AI Agent** is a system that uses Artificial Intelligence to perform tasks autonomously to achieve a specific goal.\n\nWhile a standard AI (like a basic chatbot) answers questions, an AI Agent **takes actions.**\n\nThink of it this way: \n*   **Standard AI (ChatGPT):** Like an encyclopedia. You ask it a question, and it gives you information.\n*   **AI Agent:** Like an intern. You give it a goal (e.g., "Research this company and write a summary"), and it decides which steps to take, uses tools to find information, and completes the job without you guiding every click.\n\n---\n\n### The 4 Pillars of an AI Agent\nTo be considered an "agent," the system generally needs four components:\n\n1.  **The Brain (Reasoning):** Usually a Large Language Model (LLM) like GPT-4 or Claude. It processes information, makes plans, and decides what to do next.\n2.  **Planning:** The agent breaks down a complex goal (e.g., "Plan a vacation") into smaller sub-tasks (Search flights → Find hotels → Check weather → Create itinerary).\n3.  **Memory:** \n    *   *Short-term memory:* Keeping track of the current steps.\n    *   *Long-term memory:* Learning from past interactions or retrieving data from documents.\n4.  **Tools (Action):** This is what makes it an agent. It can interact with the outside world by using APIs, searching the web, sending emails, or running code.\n\n---\n\n### How an AI Agent Works (The Loop)\nInstead of a simple "Input → Output" flow, an agent works in a **loop**:\n\n1.  **Perceive:** The agent looks at the goal and the current environment.\n2.  **Think:** It asks itself, "What is the first thing I need to do to reach this goal?"\n3.  **Act:** It uses a tool (e.g., searches Google).\n4.  **Observe:** It looks at the results of its action ("I found three flights").\n5.  **Repeat:** It continues this loop until the task is finished.\n\n---\n\n### Real-World Examples\n*   **Customer Support Agents:** An agent that doesn\'t just chat but can actually look up your order in a database, process a refund, and send you a confirmation email.\n*   **Coding Agents:** Tools like *Devin* or *GitHub Copilot Workspace* that can find a bug, write a fix, test the code, and submit a pull request.\n*   **Research Agents:** You give it a topic; it searches 20 different websites, summarizes the findings, and creates a formatted report.\n*   **Personal Assistants:** An agent that has access to your calendar and email, and can autonomously negotiate a meeting time with a colleague.\n\n---\n\n### Why are they a big deal?\nAI Agents represent the shift from **Generative AI** (creating content) to **Agentic AI** (executing workflows). \n\nThe goal of the tech industry is to move away from humans having to "copy-paste" between different tabs and apps. Instead, you tell the agent what you want to happen, and the agent navigates the software on your behalf.\n\n### Summary: Chatbot vs. Agent\n| Feature | Chatbot (Standard AI) | AI Agent |\n| :--- | :--- | :--- |\n| **Input** | User Prompt | High-level Goal |\n| **Action** | Generates Text | Executes Tasks |\n| **Autonomy** | Follows specific instructions | Self-corrects and plans steps |\n| **Tools** | Limited to internal data | Uses Web, APIs, and Software |\n| **Example** | "Write a poem about dogs." | "Find the cheapest dog food online and buy it." |'
